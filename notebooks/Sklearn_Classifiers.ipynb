# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import tweet_preprocess_mod as pre
import time
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import twitter_samples
from random import shuffle
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import (
    BernoulliNB,
    ComplementNB,
    MultinomialNB
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

# %%
pos_tweets = [" ".join(pre.process_tweet(t)) for t in twitter_samples.strings("positive_tweets.json")]
neg_tweets = [" ".join(pre.process_tweet(t)) for t in twitter_samples.strings("negative_tweets.json")]
all_tweets = pos_tweets + neg_tweets
shuffle(all_tweets)

# %% [markdown]
# Extract the words from positive and negative tweets:

# %%
pos_words = []
neg_words = []
for p_t in pos_tweets:
    words = nltk.word_tokenize(p_t)
    for word in words:
        pos_words.append(word)
for n_t in neg_tweets:
    words = nltk.word_tokenize(n_t)
    for word in words:
        neg_words.append(word)

# %% [markdown]
# Find frequency and remove common words:

# %%
pos_fd = nltk.FreqDist(pos_words)
neg_fd = nltk.FreqDist(neg_words)
common_Set = set(pos_fd).intersection(neg_fd)

for word in common_Set:
    del pos_fd[word]
    del neg_fd[word]

# %%
top_pos = {word for word, count in pos_fd.most_common(10)}
top_neg = {word for word, count in neg_fd.most_common(10)}

top_pos
# Out:
# {'fantastic',
#  'fback',
#  'flipkartfashionfriday',
#  'followfriday',
#  'happiness',
#  'here',
#  'stats',
#  'unfollowers',
#  'warsaw',
#  'youth'}

# %%
top_neg
# Out:
# {'beli̇eve',
#  'justi̇n',
#  'pray',
#  'wi̇ll',
#  'zayniscomingbackonjuly',
#  '♛',
#  '》',
#  'ｍｅ',
#  'ｓｅｅ',
#  '😩'}

# %% [markdown]
# -----------------------
# Feature Extraction:

# %%
vader = SentimentIntensityAnalyzer()

# %%
def extract_features(tweet):
    features = dict()
    wordcount = 0
    compound_scores = list()
    positive_scores = list()
    words = nltk.word_tokenize(tweet)

    for word in words:
        if word.lower() in top_pos:
            wordcount += 1

    compound_scores.append(vader.polarity_scores(tweet)["compound"])
    positive_scores.append(vader.polarity_scores(tweet)["pos"])

    features["compound"] = sum(compound_scores) + 1
    features["positive"] = sum(positive_scores)
    features["wordcount"] = wordcount

    return features

# %%
features = [
    (extract_features(tweet), "pos")
    for tweet in pos_tweets
]
features.extend([
    (extract_features(tweet), "neg")
    for tweet in neg_tweets
])

shuffle(features)
train, test = train_test_split(features, test_size=0.5)

# %%
features
# Out:
# [({'compound': 1.3612, 'positive': 0.477, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.3252, 'positive': 0.368, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7717, 'positive': 0.691, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.6166, 'positive': 0.801, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4588, 'positive': 0.6, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.6486, 'positive': 0.431, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7506, 'positive': 0.649, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4588, 'positive': 0.5, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.9484, 'positive': 0.355, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.802, 'positive': 0.455, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.872, 'positive': 0.316, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.5106000000000002, 'positive': 1.0, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7351, 'positive': 0.554, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.4577, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7096, 'positive': 0.425, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.3002, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.0, 'positive': 0.0, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4588, 'positive': 0.3, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.9217, 'positive': 0.595, 'wordcount': 1}, 'pos'),
#  ({'compound': 1.0258, 'positive': 0.319, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.8481, 'positive': 0.531, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.4588, 'positive': 0.3, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.8779, 'positive': 0.771, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.802, 'positive': 0.783, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7579, 'positive': 0.714, 'wordcount': 1}, 'pos'),
#  ({'compound': 1.3182, 'positive': 0.515, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.22829999999999995, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.6435, 'positive': 0.509, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7783, 'positive': 0.493, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.6182000000000001, 'positive': 0.146, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.4588, 'positive': 0.375, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.6388, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.8934, 'positive': 0.614, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7096, 'positive': 0.349, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7096, 'positive': 0.396, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4588, 'positive': 0.231, 'wordcount': 0}, 'pos'),
#  ({'compound': 1
 'wordcount': 0}, 'pos'),
#  ({'compound': 1.9524, 'positive': 0.68, 'wordcount': 1}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7783, 'positive': 0.459, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7096, 'positive': 0.541, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.4577, 'positive': 0.199, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.9524, 'positive': 0.68, 'wordcount': 1}, 'pos'),
#  ({'compound': 0.9484, 'positive': 0.326, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.8074, 'positive': 0.892, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.2904, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7096, 'positive': 0.283, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.6705, 'positive': 0.647, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.9283, 'positive': 0.229, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.4577, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.9432, 'positive': 0.694, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.3412, 'positive': 0.445, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.6486, 'positive': 0.639, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.9484, 'positive': 0.314, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.30920000000000003, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.34, 'positive': 0.63, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.6907999999999999, 'positive': 0.382, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.28159999999999996, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.8481, 'positive': 0.505, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.6705, 'positive': 0.647, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.8271, 'positive': 0.635, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5061, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.0, 'positive': 0.33, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.8469, 'positive': 0.371, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.38759999999999994, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7269, 'positive': 0.604, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.6124, 'positive': 0.833, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.34, 'positive': 0.545, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7096, 'positive': 0.425, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.75, 'positive': 0.218, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.3182, 'positive': 0.515, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.6388, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.3182, 'positive': 0.697, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5061, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.6486, 'positive': 0.57, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4588, 'positive': 0.6, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.9022000000000001, 'positive': 0.924, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.3742, 'positive': 0.205, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.4404, 'positive': 0.244, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.8469, 'positive': 0.319, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.802, 'positive': 0.53, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.6369, 'positive': 0.634, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7579, 'positive': 0.638, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.4588, 'positive': 0.75, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.20940000000000003, 'positive': 0.106, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.4588, 'positive': 0.75, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.8834, 'positive': 0.774, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.24939999999999996, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7096, 'positive': 0.855, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4767000000000001, 'positive': 0.506, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4588, 'positive': 0.5, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5061, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.1775, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.75, 'positive': 0.279, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.9062000000000001, 'positive': 0.739, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.4588, 'positive': 0.5, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.2732, 'positive': 0.336, 'wordcount': 0}, 'neg'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7717, 'positive': 0.77, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.1372, 'positive': 0.312, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.3182, 'positive': 0.515, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.8176, 'positive': 1.0, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.6182000000000001, 'positive': 0.159, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7506, 'positive': 0.416, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.0, 'positive': 0.0, 'wordcount': 0}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.9647999999999999, 'positive': 0.735, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7429999999999999, 'positive': 0.646, 'wordcount': 1}, 'pos'),
#  ({'compound': 0.5596, 'positive': 0.0, 'wordcount': 0}, 'neg'),
#  ({'compound': 1.7096, 'positive': 0.541, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.3182, 'positive': 0.434, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.9268999999999998, 'positive': 1.0, 'wordcount': 0}, 'pos'),
#  ({'compound': 1.7429999999999999, 'positive': 0.88, 'wordcount': 0}, 'pos'),
#  ...]

# %% [markdown]
# -----------------------
# Classifiers:

# %%
classifiers = {
    "BernoulliNB": BernoulliNB(),
    "ComplementNB": ComplementNB(),
    "MultinomialNB": MultinomialNB(),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "LogisticRegression": LogisticRegression(),
    "MLPClassifier": MLPClassifier(max_iter=1000),
    "AdaBoostClassifier": AdaBoostClassifier(),
}

# %%
for name, sklearn_classifier in classifiers.items():
    classifier = nltk.classify.SklearnClassifier(sklearn_classifier)
    classifier.train(train)

    acc = nltk.classify.accuracy(classifier, test)
    print(f"{acc:.2%} - {name}")
# Out:
# 76.24% - BernoulliNB
# 68.24% - ComplementNB
# 65.92% - MultinomialNB
# 91.90% - KNeighborsClassifier
# 90.78% - DecisionTreeClassifier
# 92.52% - RandomForestClassifier
# 89.50% - LogisticRegression
# 89.52% - MLPClassifier
# 89.92% - AdaBoostClassifier
