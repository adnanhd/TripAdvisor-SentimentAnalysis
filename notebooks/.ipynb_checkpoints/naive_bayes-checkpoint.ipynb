# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import tweet_preprocess_module as pre
from nltk.corpus import stopwords, twitter_samples

import csv
import numpy as np
import pandas as pd

from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %% [markdown]
# Hazır veriler:

# %%
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# Yardımcı fonksiyonlar:

# %%
def count_tweets(tweets: list, ys: list):
    """
    Calculates the words frequency and matches it with it's y value.
            
    Returns:
        freqs(dict): {(word, y): frequency}.
    """
    
    freqs = {}
    for y, tweet in zip(ys, tweets):
        clean_tweet = pre.process_tweet(tweet)
        for word in clean_tweet:
            pair = (word, y)
            if pair in freqs:
                freqs[pair] += 1
            else:
                freqs[pair] = 1

    return freqs


def lookup(freqs: dict, word: str, label: int):
    """
    Looks up the given word's frequency.
    
    Returns:
        n(int): frequency.
    """
    n = 0
    pair = (word, label)
    if pair in freqs:
        n = freqs[pair]

    return n

# %%
freqs = count_tweets(train_x, train_y)

freqs[("happy", 1)]
# Out:
# 150

# %% [markdown]
# Naive Bayes fonksiyonları:

# %%
def train_naive_bayes(freqs: dict, train_x: list, train_y: list):
    """
    Calculates the prior and the likelihood.
    """
    loglikelihood = {}
    logprior = 0

    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    N_pos = N_neg = 0
    for pair in freqs.keys():
        if pair[1] > 0:
            N_pos += freqs[pair]
        else:
            N_neg += freqs[pair]

    D = len(train_y)
    D_pos = (len(list(filter(lambda x: x > 0, train_y))))
    D_neg = (len(list(filter(lambda x: x <= 0, train_y))))
    logprior = np.log(D_pos) - np.log(D_neg)

    for word in vocab:
        freq_pos = lookup(freqs, word, 1)
        freq_neg = lookup(freqs, word, 0)

        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        loglikelihood[word] = np.log(p_w_pos/p_w_neg)

    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)

loglikelihood
# Out:
# {'painting': 0.0036396764474497336,
#  'wavy': -0.6895075041124956,
#  'stumble': 0.6967868570073951,
#  'ankle': -1.09497261222066,
#  'afterschool': -0.6895075041124956,
#  'hahays': -0.6895075041124956,
#  'lineup': 0.6967868570073951,
#  'sorrryyy': -0.6895075041124956,
#  'دعمم': 0.6967868570073951,
#  'retweeting': 1.3899340375673404,
#  'desire': 0.6967868570073951,
#  'للحياة': 0.6967868570073951,
#  'plant': 0.2913217488992307,
#  'popsicle': 0.6967868570073951,
#  'ejayster': 0.6967868570073951,
#  'bitchface': 0.6967868570073951,
#  'louis': 0.5144653002134403,
#  'niam': 0.6967868570073951,
#  'outboarding': 0.6967868570073951,
#  'opixer': -0.6895075041124956,
#  'vex': 0.6967868570073951,
#  'awesome': 1.7953991456755047,
#  'vampire': 1.1022519651155596,
#  'lew': -0.6895075041124956,
#  'a9': -1.09497261222066,
#  'suede': -0.6895075041124956,
#  'kme': -0.6895075041124956,
#  'raw': 0.6967868570073951,
#  'bringmethehorizon': -0.6895075041124956,
#  'thnks': 0.6967868570073951,
#  'eintlik': -0.6895075041124956,
#  'courgette': 0.6967868570073951,
#  'wanted': -0.6895075041124956,
#  "could've": -0.6895075041124956,
#  'reservations@sandsbeach.eu': 0.6967868570073951,
#  'help@veryhq.co.uk': -0.6895075041124956,
#  'jim': 0.0036396764474497336,
#  'subliminal': 0.6967868570073951,
#  "spot's": 0.6967868570073951,
#  'tanned': -0.6895075041124956,
#  '😆': -1.09497261222066,
#  'tissue': 0.6967868570073951,
#  'donate': 0.6967868570073951,
#  'snapchatme': -1.7881197927806052,
#  'whomosexual': 0.6967868570073951,
#  'nowdays': -0.6895075041124956,
#  'replay': 0.0036396764474497336,
#  'winchester': -0.6895075041124956,
#  'smell': 0.0036396764474497336,
#  'teampositive': 0.6967868570073951,
#  'disagree': 0.6967868570073951,
#  'wing': -0.6895075041124956,
#  'apps': 0.0036396764474497336,
#  'niende': -0.6895075041124956,
#  'passing': 0.6967868570073951,
#  'wwat': 1.1022519651155596,
#  'angle.nelson': 0.6967868570073951,
#  'brb': 0.0036396764474497336,
#  'mager': -0.6895075041124956,
#  'iran': -0.6895075041124956,
#  'coffe': 1.1022519651155596,
#  'rmtour': -0.6895075041124956,
#  'follow': 0.04827183046821812,
#  'lu': 0.0036396764474497336,
#  'startupph': 0.6967868570073951,
#  'kinickers': 0.6967868570073951,
#  'misundersranding': -0.6895075041124956,
#  'dipikirin': 0.6967868570073951,
#  'rize': -0.6895075041124956,
#  'boy': 0.1706937611106159,
#  'povertyyouareevil': -0.6895075041124956,
#  'cracked': -0.6895075041124956,
#  'halaaang': -0.6895075041124956,
#  'ladolcevitainluxembourg@hotmail.com': 0.6967868570073951,
#  'mne': 0.6967868570073951,
#  'attention': 0.40910478455561416,
#  'dodge': 0.6967868570073951,
#  'rest': -0.5841469884546694,
#  'moviee': 0.0036396764474497336,
#  'double': -0.2840423960043311,
#  'ad': 1.1022519651155596,
#  'fragment': -0.6895075041124956,
#  'prelim': 0.6967868570073951,
#  'connection': -0.6895075041124956,
#  'doomsday': -0.6895075041124956,
#  'ca': 0.6967868570073951,
#  'filming': 1.1022519651155596,
#  'nat': -0.6895075041124956,
#  'acne': -1.09497261222066,
#  'barefooted': -0.6895075041124956,
#  'hahaha': 0.0036396764474497336,
#  'linguist': -0.6895075041124956,
#  'ry': -0.6895075041124956,
#  'period': -0.6895075041124956,
#  'warsaw': 3.8103021662177694,
#  'hse': -0.6895075041124956,
#  'lack': 1.1022519651155596,
#  'wynter': 0.6967868570073951,
#  'rocro': 0.6967868570073951,
#  'running': 0.6967868570073951,
#  'naaan': -0.6895075041124956,
#  'evil': 0.0036396764474497336,
#  'sleepy': -1.3826546846724408,
#  "verity's": -0.6895075041124956,
#  'a6': 0.6967868570073951,
#  'appeasement': 0.6967868570073951,
#  'author': 1.1022519651155596,
#  'gyllenhaal': -0.6895075041124956,
#  'bank': -1.5004377203288244,
#  'fever': -1.2491232920479183,
#  'shittier': -0.6895075041124956,
#  'bill': -0.17868188034650503,
#  'finale': -0.6895075041124956,
#  "school's": 0.6967868570073951,
#  'chance': -1.3181161635348695,
#  'baloney': 0.6967868570073951,
#  'bobble': -0.6895075041124956,
#  "blaine's": -0.6895075041124956,
#  'difficiency': -0.6895075041124956,
#  'dual': -0.6895075041124956,
#  'goodluck': 0.0036396764474497336,
#  'dance': -1.09497261222066,
#  'tomcat': -0.6895075041124956,
#  'boi': 0.6967868570073951,
#  'ausfailia': -0.6895075041124956,
#  'floor': -1.09497261222066,
#  '💅🏽': 0.6967868570073951,
#  'dearslim': 1.1022519651155596,
#  'religion': 0.6967868570073951,
#  'minute': -0.3328325601737632,
#  'frog': -1.09497261222066,
#  'helium': -0.6895075041124956,
#  'hashbrowns': -0.6895075041124956,
#  'legendary': -0.6895075041124956,
#  'verge': 0.6967868570073951,
#  'stripe': -0.6895075041124956,
#  'poppin': -0.6895075041124956,
#  'quietly': -1.09497261222066,
#  'mention': 1.0021685065585768,
#  'clientvisit': 0.6967868570073951,
#  'base': 0.40910478455561416,
#  'sexysasunday': -0.40182543166071466,
#  'charli': -0.6895075041124956,
#  'videogames': 0.6967868570073951,
#  'cover': 0.984468929459176,
#  'isibaya': -0.6895075041124956,
#  'kebab': -0.6895075041124956,
#  'haaa': 0.6967868570073951,
#  'mbulelo': -0.6895075041124956,
#  'fav': 2.48854632623545,
#  'telecom': 1.1022519651155596,
#  'sweetheart': 0.6967868570073951,
#  'ladder': -1.09497261222066,
#  'today': -0.019088574630106384,
#  "masha'allah": 0.6967868570073951,
#  'straight': -1.6057982359866505,
#  'h_my_king': -0.6895075041124956,
#  'tessnzach': 0.6967868570073951,
#  'jackson': -1.6057982359866505,
#  'cornish': 0.6967868570073951,
#  'ima': 0.6967868570073951,
#  'chant': 1.1022519651155596,
#  'inner': 1.1022519651155596,
#  'rosebury': -0.6895075041124956,
#  'world': 0.40910478455561416,
#  'description': -0.40182543166071466,
#  'advaddict': 0.6967868570073951,
#  'price': -0.21950387486675996,
#  'mateo': -0.6895075041124956,
#  'excuse': 0.40910478455561416,
#  'commit': -1.09497261222066,
#  'dan': 0.6967868570073951,
#  'overload': 0.6967868570073951,
#  "you's": -1.09497261222066,
#  'facetime': 0.0036396764474497336,
#  'doug': 1.1022519651155596,
#  'oshieer': 0.6967868570073951,
#  'selenators': -0.6895075041124956,
#  'sona': 0.6967868570073951,
#  'seriously': -2.19358490088877,
#  'fieldtrips': -0.6895075041124956,
#  'olur': 0.6967868570073951,
#  'randy': 0.6967868570073951,
#  'art': 0.18596123324140432,
#  'hangin': -0.6895075041124956,
#  'tompolo': 0.6967868570073951,
#  'fresherstofinals': -0.6895075041124956,
#  'ayala': -0.6895075041124956,
#  'java': 0.6967868570073951,
#  'baechu': -0.6895075041124956,
#  'plaster': -1.09497261222066,
#  'inspire': 1.61307758888155,
#  'fenestoscope': -0.6895075041124956,
#  "australia's": -0.6895075041124956,
#  'youngnaturalleaders': 0.6967868570073951,
#  'clock': -0.40182543166071466,
#  'reckon': -0.6895075041124956,
#  'nudge': 0.6967868570073951,
#  'iyalaya': -0.6895075041124956,
#  'fam': 0.0036396764474497336,
#  'quan': 0.6967868570073951,
#  'vinny': 0.6967868570073951,
#  'european': -1.3826546846724408,
#  '<---': 1.1022519651155596,
#  'ure': -0.40182543166071466,
#  'oven': 1.1022519651155596,
#  'bantime': 0.6967868570073951,
#  'auto-focus': 0.6967868570073951,
#  'nurse': -0.6895075041124956,
#  'ehh': -0.6895075041124956,
#  'junhee': -0.6895075041124956,
#  'omgg': 0.6967868570073951,
#  'obi': 0.6967868570073951,
#  'qt': -0.6895075041124956,
#  'ehdar': -0.6895075041124956,
#  'phulani': 0.6967868570073951,
#  'numbero': 0.6967868570073951,
#  'romantica': -0.6895075041124956,
#  'pamer': 0.6967868570073951,
#  'hardheaded': -0.6895075041124956,
#  'leia': 0.6967868570073951,
#  'yumu-youtuber': -0.6895075041124956,
#  'tony': 1.1022519651155596,
#  'relationship': -0.21950387486675996,
#  'closet': -0.6895075041124956,
#  'still': -1.0127345139836879,
#  'cerbchan': 0.6967868570073951,
#  'pipe': -0.6895075041124956,
#  'lmfao': -1.09497261222066,
#  'hasya': -0.6895075041124956,
#  'elsa': -0.6895075041124956,
#  'pedant': 0.6967868570073951,
#  'mugshot': -0.6895075041124956,
#  'engine': 0.6967868570073951,
#  'callinganimalabusehotlineasap': 0.6967868570073951,
#  'nicely': -0.6895075041124956,
#  'unfriend': -0.6895075041124956,
#  'communal': 0.6967868570073951,
#  'jilla': 0.6967868570073951,
#  'onwards': -0.6895075041124956,
#  'recommend': 1.1022519651155596,
#  'labour': 1.3899340375673404,
#  'weather': -1.1750153198941964,
#  'shepherd': -1.09497261222066,
#  'smug': 0.6967868570073951,
#  'fully': 1.1022519651155596,
#  'manila': -1.3826546846724408,
#  'naeun': -0.6895075041124956,
#  'ted': 0.6967868570073951,
#  'illustration': 0.6967868570073951,
#  'beware': -0.6895075041124956,
#  'spec': 0.6967868570073951,
#  'announcement': -0.6895075041124956,
#  'pose': 1.1022519651155596,
#  'vincent': 0.6967868570073951,
#  'late': -0.5071859473185409,
#  'salmon': 0.6967868570073951,
#  'risky': -0.6895075041124956,
#  'heard': 0.0036396764474497336,
#  'merch': -0.6895075041124956,
#  'groupie': 0.6967868570073951,
#  'cheshire': 0.6967868570073951,
#  "slovakia's": -0.6895075041124956,
#  'limpopo': 0.6967868570073951,
#  'source': 1.3899340375673404,
#  'slacke': -0.6895075041124956,
#  'hyungbot': 0.6967868570073951,
#  '🎉': 0.9199304083216048,
#  'couldve': -0.6895075041124956,
#  'anxiety': -0.6895075041124956,
#  'preform': -0.6895075041124956,
#  'ask': 0.16398232652262915,
#  'stretch': -0.6895075041124956,
#  'bigbang': -0.6895075041124956,
#  'ami': -0.6895075041124956,
#  'regional': 0.0036396764474497336,
#  'meh': -1.3826546846724408,
#  'odoo': -1.09497261222066,
#  'luminous': -0.6895075041124956,
#  'fireball': 0.6967868570073951,
#  'blew': 0.6967868570073951,
#  'nxt': 0.0036396764474497336,
#  'admin_myung': -0.6895075041124956,
#  'campaign': 0.0036396764474497336,
#  'hahahaa': 0.6967868570073951,
#  'gleam': 0.6967868570073951,
#  'practicing': 0.6967868570073951,
#  'youth@bipolaruk.org.uk': 0.6967868570073951,
#  'tweetin': 0.0036396764474497336,
#  'habe': -0.6895075041124956,
#  'avoid': -1.09497261222066,
#  'thirstyyy': -0.6895075041124956,
#  'owe': 0.6967868570073951,
#  'toast': 0.0036396764474497336,
#  'unlisted': 0.6967868570073951,
#  'capeee': -0.6895075041124956,
#  'hopeful': -0.6895075041124956,
#  'ic': -0.6895075041124956,
#  'tnc': 0.6967868570073951,
#  'wae': -0.6895075041124956,
#  'rakyat': 0.6967868570073951,
#  'lukris': 0.6967868570073951,
#  'berangkaat': 0.6967868570073951,
#  'hipster': 0.6967868570073951,
#  'perspective': -0.6895075041124956,
#  'fansign': -0.6895075041124956,
#  '🌞': 0.6967868570073951,
#  'sick': -2.799720704459085,
#  'tiring': -0.6895075041124956,
#  'rename': 0.6967868570073951,
#  'aunt': 0.6967868570073951,
#  'ripsandrabland': -0.6895075041124956,
#  'suitcase': 1.1022519651155596,
#  'rajnigandha': 0.6967868570073951,
#  'alright': 0.40910478455561416,
#  'needicecreamnow': -0.6895075041124956,
#  'suzy': -0.6895075041124956,
#  'dmed': -0.6895075041124956,
#  'killin': 0.6967868570073951,
#  "dostoevsky's": 0.6967868570073951,
#  'aside': 0.6967868570073951,
#  'chapter': -0.6895075041124956,
#  'minhyuks': -0.6895075041124956,
#  'isi': 0.0036396764474497336,
#  'blight': -0.6895075041124956,
#  'puppy': 0.0036396764474497336,
#  'doh': 0.6967868570073951,
#  'comfy': 0.0036396764474497336,
#  'ryan': 0.6967868570073951,
#  'triangle': 1.1022519651155596,
#  'knowing': 0.0036396764474497336,
#  'repeat': 0.2913217488992307,
#  'steam': -0.40182543166071466,
#  'alvadhaau': -0.6895075041124956,
#  'magicalkenya': 0.6967868570073951,
#  'album': -0.6895075041124956,
#  'fraand': -0.6895075041124956,
#  'basemaps': 0.6967868570073951,
#  "kinara's": -0.6895075041124956,
#  'halla': 0.6967868570073951,
#  'appointment': -0.6895075041124956,
#  'effective': 0.6967868570073951,
#  'fleekile': 0.6967868570073951,
#  'educampakl': 0.6967868570073951,
#  'gaya': 0.6967868570073951,
#  'pfb': 0.0036396764474497336,
#  'polish': 0.6967868570073951,
#  'spell': 1.1022519651155596,
#  'phonegraphs': 0.6967868570073951,
#  'mjhe': -1.09497261222066,
#  'yey': 0.6967868570073951,
#  'responsibility': -0.6895075041124956,
#  'easy': 0.10900019210527591,
#  'ditch': 0.6967868570073951,
#  'pee': -1.09497261222066,
#  'plea': -1.3826546846724408,
#  'blinkin': -0.6895075041124956,
#  'snit': -0.6895075041124956,
#  'fiesta': 0.6967868570073951,
#  'pearson': 0.6967868570073951,
#  'booty': 0.0036396764474497336,
#  'joim': 0.6967868570073951,
#  'fotoset': 0.6967868570073951,
#  'impression': 0.6967868570073951,
#  'promotion': -0.6895075041124956,
#  'agesss': -0.6895075041124956,
#  'tologooo': 0.6967868570073951,
#  'delay': -1.09497261222066,
#  'mosquitoe': -0.6895075041124956,
#  'convince': -1.09497261222066,
#  '★': 1.7953991456755047,
#  'mahone': -0.6895075041124956,
#  'prinsesa': 0.6967868570073951,
#  'steel': 0.0036396764474497336,
#  'simon': 0.6967868570073951,
#  'worried': -1.09497261222066,
#  'hot': 0.745577021176827,
#  'yeeeyyy': 0.6967868570073951,
#  'moar': 1.1022519651155596,
#  'unlock': 0.6967868570073951,
#  'sunny': 0.9199304083216048,
#  'cute': -0.5162357828384587,
#  'monash': -0.6895075041124956,
#  'saar': 0.6967868570073951,
#  "u're": 0.6967868570073951,
#  'example': -0.6895075041124956,
#  'foood': -0.6895075041124956,
#  'gottolovebanks': 0.6967868570073951,
#  'mubarak': 0.6967868570073951,
#  'exposure': 0.6967868570073951,
#  'israel': -0.6895075041124956,
#  'findyourfit': 0.6967868570073951,
#  'norwegian': -0.6895075041124956,
#  'impeccable': 1.1022519651155596,
#  'venice': 0.0036396764474497336,
#  'petrol': -0.6895075041124956,
#  'liverpool': -1.09497261222066,
#  'yesterday': -0.6895075041124956,
#  'thanks': 1.4302079367052802,
#  'survival': -0.6895075041124956,
#  'feminist': 0.6967868570073951,
#  'chikka': -0.6895075041124956,
#  'yeeaayy': 0.6967868570073951,
#  'fangirl': 1.1022519651155596,
#  'vandag': -0.6895075041124956,
#  'band': 0.0036396764474497336,
#  'lolipop': -0.6895075041124956,
#  'madison': 0.6967868570073951,
#  'tomorrow': 0.17353871324284725,
#  'kingdom': 0.0036396764474497336,
#  'stationary': 0.6967868570073951,
#  'dumb': -0.6895075041124956,
#  'sunjam': 0.6967868570073951,
#  'que': -0.6895075041124956,
#  'basil': 0.0036396764474497336,
#  'settle': 0.6967868570073951,
#  "what's": -0.07046829570627221,
#  'lazy': -0.40182543166071466,
#  'bebe': 0.0036396764474497336,
#  'forgive': 1.1022519651155596,
#  'jerk': -0.6895075041124956,
#  'probably': 0.13717106907197227,
#  'feytyaz': 0.6967868570073951,
#  'ff': 2.974054142017151,
#  'chibi': 0.6967868570073951,
#  'address': 1.1022519651155593,
#  'mayday': -0.6895075041124956,
#  'lovable': 0.6967868570073951,
#  'amen': 1.1022519651155596,
#  'nugget': -0.6895075041124956,
#  'oreo': -0.6895075041124956,
#  'whereisthesun': -0.6895075041124956,
#  'quetiapine': -0.6895075041124956,
#  'platonic': 0.6967868570073951,
#  'starving': -0.6895075041124956,
#  'movement': -0.6895075041124956,
#  'magic': 0.6967868570073951,
#  'editor': -0.6895075041124956,
#  'loryn.good@lincs-chamber.co.uk': 0.6967868570073951,
#  'experiment': -0.40182543166071466,
#  'event': 0.984468929459176,
#  "can't": -1.5345707266982826,
#  'digital': -1.7881197927806052,
#  'palace': 1.1022519651155596,
#  'hash': 0.6967868570073951,
#  'thurston': -0.6895075041124956,
#  'yummmyyy': 0.6967868570073951,
#  'naw': -1.3826546846724408,
#  'floofs': 0.6967868570073951,
#  '☺': 0.40910478455561416,
#  'iloveyouu': -0.6895075041124956,
#  'rohingya': -0.6895075041124956,
#  'pressrelease': 0.6967868570073951,
#  'intellect': 0.6967868570073951,
#  'thehungergames': 0.6967868570073951,
#  '🎀': -0.6895075041124956,
#  'aftie': 0.6967868570073951,
#  'sulli': -0.6895075041124956,
#  'dobar': 0.6967868570073951,
#  'difference': 0.0036396764474497336,
#  'hand-lettering': 0.6967868570073951,
#  'morality': -0.6895075041124956,
#  'haveagoodday': 0.6967868570073951,
#  'nowt': -0.6895075041124956,
#  'fml': -1.3826546846724408,
#  'shiva': 0.6967868570073951,
#  'shitfaced': 0.6967868570073951,
#  'sandwich': -1.6057982359866505,
#  'mesh': -0.6895075041124956,
#  'mnwreeen': 0.6967868570073951,
#  'meni': 0.6967868570073951,
#  'stone': 0.6967868570073951,
#  '¿': -0.6895075041124956,
#  'naggy': 0.6967868570073951,
#  'name': -0.07046829570627221,
#  'sends': 0.6967868570073951,
#  'lorna': 0.6967868570073951,
#  'wonderful': 1.4505586593837754,
#  'railway': 0.0036396764474497336,
#  'relaxes': -0.6895075041124956,
#  'physically': -1.3826546846724408,
#  'year': -0.10758595866277453,
#  "f'ing": 0.6967868570073951,
#  'vehicle': -1.7881197927806052,
#  'mein': 0.0036396764474497336,
#  'mr2': 0.6967868570073951,
#  '🍰': 1.7953991456755047,
#  'vocal': 0.0036396764474497336,
#  'someone': -0.2840423960043311,
#  'wed': 0.40910478455561416,
#  'billionaire': -0.6895075041124956,
#  'promo': 0.0036396764474497336,
#  'standrews': 0.6967868570073951,
#  'stylish': 0.6967868570073951,
#  'little': 0.5144653002134404,
#  'feelgoodfriday': -0.6895075041124956,
#  'prob': -0.2840423960043311,
#  'considerably': 0.6967868570073951,
#  'specialist': 0.6967868570073951,
#  'eric': 0.40910478455561416,
#  'john': 1.949549825502763,
#  'machaya': -0.6895075041124956,
#  'wouldve': -0.6895075041124956,
#  'dedicatedfan': 0.6967868570073951,
#  'jersey': -1.09497261222066,
#  'infra': -0.6895075041124956,
#  'puhon': 0.6967868570073951,
#  'cretaperfectsuv': 1.1022519651155596,
#  'blaming': -0.6895075041124956,
#  'mubarik': 1.1022519651155596,
#  'todayyy': 0.6967868570073951,
#  'cayton': -0.6895075041124956,
#  'challo': -0.6895075041124956,
#  'petite': -0.6895075041124956,
#  'building': 0.40910478455561416,
#  'meooowww': 0.6967868570073951,
#  'straw': -0.6895075041124956,
#  'dreamteam': 0.6967868570073951,
#  'latin': 1.7953991456755047,
#  'naked': -0.6895075041124956,
#  'mary': 0.6967868570073951,
#  'fuller': 0.6967868570073951,
#  'hopeyou': 0.6967868570073951,
#  'cont': -1.09497261222066,
#  'saran': 0.6967868570073951,
#  'freeze': -1.09497261222066,
#  'fit': -0.2840423960043311,
#  'shortlist': 0.6967868570073951,
#  'afterwards': 0.6967868570073951,
#  "ledger's": -0.6895075041124956,
#  'pool': 0.40910478455561416,
#  'sore': 0.15779035627470794,
#  'interaction': 0.0036396764474497336,
#  'grandma': -0.6895075041124956,
#  'perf': -1.09497261222066,
#  'emirate': 0.6967868570073951,
#  'moose': 0.6967868570073951,
#  'aidzin': 0.6967868570073951,
#  'munchkins': 0.6967868570073951,
#  'lynettelowe': 0.0036396764474497336,
#  'sheskindahot': 0.6967868570073951,
#  'stroke': 0.6967868570073951,
#  '.\n.': -1.09497261222066,
#  'link': 0.3401119130686626,
#  'baz': 0.6967868570073951,
#  'code': -0.555976111487973,
#  'forneret': 0.6967868570073951,
#  'twice': -0.40182543166071466,
#  'huh': -0.8436581839397539,
#  'french': 0.5144653002134403,
#  "i've": -0.9126510554267054,
#  'overweight': -0.6895075041124956,
#  'bff': 0.0036396764474497336,
#  'horrible': -1.3826546846724408,
#  'anything.surely': -0.6895075041124956,
#  "venus's": -0.6895075041124956,
#  'fast': -0.8436581839397539,
#  'near': -0.2840423960043311,
#  'nemanja': -0.6895075041124956,
#  'guy': 0.1314730479573346,
#  'shatter': 0.6967868570073951,
#  'bakal': 0.6967868570073951,
#  'dis': -0.5071859473185409,
#  'cocky': 0.6967868570073951,
#  '🙈': 0.6967868570073951,
#  'replenish': 0.6967868570073951,
#  'dime': 0.6967868570073951,
#  'sotw': 0.6967868570073951,
#  'introduction': 0.6967868570073951,
#  '>:-(': -1.3826546846724408,
#  'yoga': -0.6895075041124956,
#  'linis': -0.6895075041124956,
#  'heap': -0.6895075041124956,
#  'doodle': 1.1022519651155596,
#  'aff': 0.6967868570073951,
#  'bar': 0.0036396764474497336,
#  'le': 0.0036396764474497336,
#  'carnival': 0.6967868570073951,
#  'orchard': 0.6967868570073951,
#  'rodfanta': -0.6895075041124956,
#  '🚖': -0.6895075041124956,
#  'gotta': -0.46636395279828585,
#  'preorder': 0.6967868570073951,
#  'tear': -1.09497261222066,
#  'humidity': 0.6967868570073951,
#  'nathanielhinanakit': -0.6895075041124956,
#  'p': -0.40182543166071466,
#  'hihihi': 0.6967868570073951,
#  'mel': -0.6895075041124956,
#  'pass': -0.10172083921037654,
#  'lourdes': -0.6895075041124956,
#  'fee': -0.40182543166071466,
#  'britain': 0.0036396764474497336,
#  "barrista's": -0.6895075041124956,
#  'poopie': -0.6895075041124956,
#  'anyway': 0.632248335869824,
#  'collab': 1.1022519651155596,
#  'riri': -0.6895075041124956,
#  'nope': 0.15779035627470794,
#  'hoodie': 1.1022519651155596,
#  'sr': -0.6895075041124956,
#  'thankies': 0.6967868570073951,
#  'semester': -1.09497261222066,
#  'okayy': 1.1022519651155596,
#  'chinua': 0.6967868570073951,
#  'lol': 0.44085348287019444,
#  'inspiration': 1.1022519651155596,
#  'prompt': -0.6895075041124956,
#  'foreveralone': 0.6967868570073951,
#  'icepack': -0.6895075041124956,
#  'inapropriate': -0.6895075041124956,
#  'imysm': -1.09497261222066,
#  'social': 0.9199304083216048,
#  'phonesex': 0.0036396764474497336,
#  'rela': 0.6967868570073951,
#  'seem': -0.36408510367786767,
#  'grotty': -0.6895075041124956,
#  'barely': -0.5071859473185409,
#  'startup': 1.1022519651155596,
#  'master': 0.6967868570073951,
#  'muchhh': 0.0036396764474497336,
#  'date': 0.455624800190507,
#  'banter': 0.6967868570073951,
#  'mbf': 0.0036396764474497336,
#  'thwarting': -0.6895075041124956,
#  'exhausting': -0.6895075041124956,
#  'royal': 0.40910478455561416,
#  'chrome': 0.6967868570073951,
#  'blackcountryfair': 0.6967868570073951,
#  'sleepover': -0.6895075041124956,
#  'classic': 0.6967868570073951,
#  'laughter': 0.40910478455561416,
#  'krta': 0.6967868570073951,
#  'cosplayprogress': 0.6967868570073951,
#  'rick': -0.6895075041124956,
#  'tara': 1.1022519651155596,
#  'pony': 0.6967868570073951,
#  'spread': 2.0830812181272855,
#  'market': 1.3899340375673404,
#  'united': 0.40910478455561416,
#  'seungchan': -0.6895075041124956,
#  'minuter': 0.6967868570073951,
#  'gintama': -0.6895075041124956,
#  'spend': -0.6895075041124956,
#  'county': -1.09497261222066,
#  'uts': -0.6895075041124956,
#  'allowance': -0.6895075041124956,
#  'txt_shot': -0.6895075041124956,
#  'jadines': -0.6895075041124956,
#  'm': -0.6895075041124956,
#  'hp': -1.09497261222066,
#  'koala': -0.6895075041124956,
#  'racing': -0.6895075041124956,
#  'apple': 0.0036396764474497336,
#  'badass': 0.6967868570073951,
#  'fulton': 0.6967868570073951,
#  'in-shaa-allah': 0.6967868570073951,
#  'fluent': -0.6895075041124956,
#  'taissa': -0.6895075041124956,
#  'ahahah': 0.0036396764474497336,
#  'jhalak': -0.6895075041124956,
#  'everlasting': 0.6967868570073951,
#  'duck': 0.9199304083216048,
#  'trendy': 0.6967868570073951,
#  'velvet': -0.6895075041124956,
#  'miracle': -0.6895075041124956,
#  'sobtian': 0.6967868570073951,
#  'pkwalasawaal': 0.0036396764474497336,
#  'masaantoday': 1.3899340375673404,
#  'rattle': -0.6895075041124956,
#  'pora': -0.6895075041124956,
#  'dkt': 0.6967868570073951,
#  'fu': -0.6895075041124956,
#  'surf': 0.0036396764474497336,
#  'selamathariraya': 0.6967868570073951,
#  'variety': 0.6967868570073951,
#  'laomma': -1.09497261222066,
#  'atty': -0.6895075041124956,
#  'elmoprinssi': 0.6967868570073951,
#  'thaaanks': 0.6967868570073951,
#  'hsould': -0.6895075041124956,
#  'burn': -0.5071859473185409,
#  'delegate': 0.6967868570073951,
#  'gooday': 1.3899340375673404,
#  'clicksco': 0.6967868570073951,
#  'elf': 0.0036396764474497336,
#  'daredevil': 1.1022519651155596,
#  'tight': 0.0036396764474497336,
#  'fortune': 0.0036396764474497336,
#  'iso': 0.6967868570073951,
#  'disappear': -0.6895075041124956,
#  'route': 1.1022519651155596,
#  'vietnam': -0.6895075041124956,
#  'heck': -1.09497261222066,
#  'fear': 0.0036396764474497336,
#  'ce': 0.0036396764474497336,
#  'amy': 0.6967868570073951,
#  '╮': 1.61307758888155,
#  'gol': -0.6895075041124956,
#  'bend': 1.1022519651155596,
#  'minister': 1.1022519651155596,
#  'weirddd': -0.6895075041124956,
#  'madeline': 0.6967868570073951,
#  'etsy': 0.6967868570073951,
#  'pd': -0.6895075041124956,
#  'urgently': 1.3899340375673404,
#  'miss': -2.5907854991470405,
#  'cleanse': 0.6967868570073951,
#  'dos': -0.6895075041124956,
#  'louisianashooting': -0.6895075041124956,
#  'merci': 0.6967868570073951,
#  'label': 0.6967868570073951,
#  'patml': -0.6895075041124956,
#  'tams': -0.6895075041124956,
#  'up.come': -0.6895075041124956,
#  'holder': 0.6967868570073951,
#  'lol.hook': 0.6967868570073951,
#  'nad': 0.6967868570073951,
#  'opposite': 0.6967868570073951,
#  'pamper': 0.40910478455561416,
#  'mixer': -0.6895075041124956,
#  'gold': 1.3899340375673404,
#  'breakfast': 0.0036396764474497336,
#  "stomach's": -0.6895075041124956,
#  'drone': 0.6967868570073951,
#  'jeep': 1.3899340375673404,
#  'jcreport': 0.6967868570073951,
#  'sat': -0.6895075041124956,
#  'shade': -0.6895075041124956,
#  'tracerequest': 1.1022519651155596,
#  'recent': 1.7953991456755047,
#  'nite': 0.6967868570073951,
#  'pop': 0.40910478455561416,
#  'welcoma.have': 0.6967868570073951,
#  'election': 0.0036396764474497336,
#  'tryna': -0.6895075041124956,
#  'flipkartfashionfriday': 2.836853020503666,
#  'score': -0.6895075041124956,
#  'healthy': -0.6895075041124956,
#  'hyungwon': -0.6895075041124956,
#  'egg': -1.6057982359866505,
#  'issue': -0.11414335920893368,
#  'area': 0.9199304083216048,
#  'manual': 0.0036396764474497336,
#  'iqbal': 0.6967868570073951,
#  '┳': 0.6967868570073951,
#  'wft': -0.6895075041124956,
#  'thencerest': 0.6967868570073951,
#  'faith': 0.0036396764474497336,
#  'overdue': 0.6967868570073951,
#  'sj': -1.3826546846724408,
#  'exercising': -0.6895075041124956,
#  'explanation': 1.1022519651155596,
#  'pilllow': -0.6895075041124956,
#  'body': 0.08368238412098601,
#  'wasp': -1.09497261222066,
#  'explorealberta': -0.6895075041124956,
#  'pooo': -1.09497261222066,
#  'programme': 0.0036396764474497336,
#  'pic.twitter.com/jxz2lbv6o': 0.6967868570073951,
#  'servus': 0.6967868570073951,
#  'cimbom': 0.6967868570073951,
#  'birthdaygirl': 0.6967868570073951,
#  'dota': 0.40910478455561416,
#  'actress': 0.6967868570073951,
#  'grindea': 0.6967868570073951,
#  'parijat': -0.6895075041124956,
#  'raven': -0.6895075041124956,
#  'testicle': 0.6967868570073951,
#  'mail': 1.3899340375673404,
#  'pattern': 0.6967868570073951,
#  'simpson': -0.6895075041124956,
#  'hottie': -0.6895075041124956,
#  'supportive': 0.0036396764474497336,
#  'meet': 0.0036396764474497336,
#  'redhead': 0.6967868570073951,
#  'roma': -0.6895075041124956,
#  'lyf': -0.6895075041124956,
#  'quite': 0.40910478455561405,
#  'hotfmnoaidilforariana': -1.09497261222066,
#  'far': -0.12152346650655628,
#  'benchers': 0.6967868570073951,
#  'x4': 0.6967868570073951,
#  'luxurytravel': 0.6967868570073951,
#  'calum': 0.6967868570073951,
#  'tdy': 0.6967868570073951,
#  'console': 0.0036396764474497336,
#  'certainly': 0.5144653002134403,
#  'perhaps': 0.2913217488992307,
#  'stadium': -1.6057982359866505,
#  'youre': -0.40182543166071466,
#  'x37': 0.6967868570073951,
#  'specially-marked': 0.6967868570073951,
#  'tdc': -0.6895075041124956,
#  "thát's": -0.6895075041124956,
#  'tunnel': -1.09497261222066,
#  'lfccw': -0.6895075041124956,
#  'memory': -0.21950387486675996,
#  'ouch': -0.2840423960043311,
#  'modern': 0.0036396764474497336,
#  'advisory': -0.6895075041124956,
#  'sweedy': -0.6895075041124956,
#  'unlucky': -1.09497261222066,
#  'cypher': 0.6967868570073951,
#  'photooftheday': 0.2913217488992307,
#  'silently': -0.6895075041124956,
#  'bebeee': -1.09497261222066,
#  'application': 1.1022519651155596,
#  'ferdous': -0.6895075041124956,
#  'ya': 0.5914263413495687,
#  'losing': -0.6895075041124956,
#  'main': 1.949549825502763,
#  "infinite's": -0.6895075041124956,
#  'kgola': -0.6895075041124956,
#  'lmfaoo': -0.6895075041124956,
#  'browse': 0.6967868570073951,
#  'messenger': -0.6895075041124956,
#  'spirit': -0.40182543166071466,
#  'mexican': 0.6967868570073951,
#  'x12': 1.1022519651155596,
#  'grs': 0.6967868570073951,
#  'nikki': 1.1022519651155596,
#  'castle': 0.6967868570073951,
#  'indie': 1.1022519651155596,
#  'flew': -0.6895075041124956,
#  'potter': -0.6895075041124956,
#  'xxx': 0.5632554643828724,
#  'todos': 0.6967868570073951,
#  'rlyhurts': -0.6895075041124956,
#  'mister': 1.1022519651155596,
#  'adam': 0.0036396764474497336,
#  'teeth': -1.6057982359866505,
#  'muster': -0.6895075041124956,
#  'awkward': 0.6967868570073951,
#  'couscous': 1.3899340375673404,
#  'barnstaple': 0.6967868570073951,
#  'nate': 0.0036396764474497336,
#  'whatsoever': -1.09497261222066,
#  'killer': -0.40182543166071466,
#  '∞': 0.6967868570073951,
#  'juja': -0.6895075041124956,
#  'joe': -1.09497261222066,
#  'foodiefridays': 0.6967868570073951,
#  'portsmouth': 0.6967868570073951,
#  'alternative': 1.1022519651155596,
#  'ashamed': -0.40182543166071466,
#  'obsess': 0.0036396764474497336,
#  'tweetland': 0.6967868570073951,
#  'digitalmarketing': 0.6967868570073951,
#  'rechargeable': 0.6967868570073951,
#  'chocolate': 0.0036396764474497336,
#  'oley': 0.6967868570073951,
#  'kuffar': 0.6967868570073951,
#  'young': 0.13717106907197227,
#  'stiff': 0.6967868570073951,
#  'funny': 1.1667904862531306,
#  'dp': 0.6967868570073951,
#  'knock': 0.0036396764474497336,
#  'woohoo': 1.3899340375673404,
#  'sp': -0.6895075041124956,
#  'po': 0.6967868570073951,
#  'foto': 0.6967868570073951,
#  'chswiyfxcskcalum': -0.6895075041124956,
#  'individual': 1.1022519651155596,
#  'especially': 0.2913217488992307,
#  'sigeg': -0.6895075041124956,
#  'cu': -0.6895075041124956,
#  'reach': -0.6895075041124956,
#  'letsgetmessy': 0.6967868570073951,
#  'dun': 0.6967868570073951,
#  'halfway': 0.6967868570073951,
#  'gift': -0.21950387486675996,
#  'september': 0.9199304083216048,
#  'hotwheels': -0.6895075041124956,
#  'peaceful': 1.3899340375673404,
#  'fatigue': 0.6967868570073951,
#  'zdps': 0.6967868570073951,
#  'chelsea': 0.40910478455561416,
#  'u21': 0.6967868570073951,
#  'fightstickfriday': 0.6967868570073951,
#  'fragile': -0.6895075041124956,
#  'innumerable': 0.6967868570073951,
#  'isp': 0.6967868570073951,
#  'jumma': 0.6967868570073951,
#  "they'd": -1.09497261222066,
#  'duh': 1.1022519651155596,
#  'taybigail': -0.6895075041124956,
#  'pride': 0.0036396764474497336,
#  'dasvidaniya': 0.6967868570073951,
#  'boobs': -0.6895075041124956,
#  'x24': 0.6967868570073951,
#  'pin': 0.9199304083216048,
#  'drew': 0.6967868570073951,
#  'squishy': -0.6895075041124956,
#  'laomma_couture': -0.6895075041124956,
#  'brave': 0.40910478455561416,
#  'letsfootball': -0.6895075041124956,
#  'bless': 2.0830812181272855,
#  'daring': 0.6967868570073951,
#  'pepsi': 0.6967868570073951,
#  'bnf': 0.6967868570073951,
#  'emotionally': -1.09497261222066,
#  'jiba': 0.6967868570073951,
#  'notgonnabeactivefor': -0.6895075041124956,
#  'lycra': 0.6967868570073951,
#  'ily.melanie': -0.6895075041124956,
#  'mush': -0.6895075041124956,
#  'canon': 0.0036396764474497336,
#  'fack': -0.6895075041124956,
#  'seouljins': 0.6967868570073951,
#  'luckily': 0.6967868570073951,
#  'prince': 0.6967868570073951,
#  'brag': -0.6895075041124956,
#  'dj': 0.0036396764474497336,
#  'stereo': -0.6895075041124956,
#  'addressing': -0.6895075041124956,
#  'honest': 1.1022519651155596,
#  'c64': 0.6967868570073951,
#  'delhi': 0.6967868570073951,
#  'celebration': -0.6895075041124956,
#  'kaylas': -0.6895075041124956,
#  'value': 1.1022519651155596,
#  'rain': -0.5782818690022712,
#  'wotw': 0.6967868570073951,
#  'awsme': -0.6895075041124956,
#  'village': -0.6895075041124956,
#  'ripstegi': -0.6895075041124956,
#  'brendon': -0.6895075041124956,
#  'hashtag': 1.3899340375673404,
#  'swimming': 0.0036396764474497336,
#  'anti-christ': 0.6967868570073951,
#  'happenend': -0.6895075041124956,
#  'bemecode': 0.6967868570073951,
#  'chemical': -0.6895075041124956,
#  'motherfucking': 0.6967868570073951,
#  'pakighinabi': -0.6895075041124956,
#  'tengaman': 0.6967868570073951,
#  'itv': 0.6967868570073951,
#  "shady's": -0.6895075041124956,
#  'pll': -0.6895075041124956,
#  'aswell': 0.6967868570073951,
#  'tripping': 0.6967868570073951,
#  'soap': 1.3899340375673404,
#  'bristolart': 0.6967868570073951,
#  'information': -0.5071859473185409,
#  'sikandar': 0.6967868570073951,
#  'colour': 0.0036396764474497336,
#  'biooo': -0.6895075041124956,
#  'panel': -0.6895075041124956,
#  'kurta': 1.3899340375673404,
#  'giddy': -0.6895075041124956,
#  'thinking': 0.40910478455561416,
#  'publication': 0.6967868570073951,
#  'reserve': 1.1022519651155596,
#  'motavators': -0.6895075041124956,
#  'rabbit': 0.6967868570073951,
#  'incoming': 0.6967868570073951,
#  'deo': 0.6967868570073951,
#  'bros': 0.6967868570073951,
#  'g': 0.0036396764474497336,
#  'geneva': -0.6895075041124956,
#  'faves': 0.6967868570073951,
#  'home': -0.9221297993812491,
#  'tasty': 0.6967868570073951,
#  'attend': 0.0036396764474497336,
#  'gee': -0.6895075041124956,
#  'burberry': -0.6895075041124956,
#  '2-4': -0.6895075041124956,
#  'pcb': -0.6895075041124956,
#  'search': -1.3826546846724408,
#  'angie': -0.6895075041124956,
#  'mag': -1.09497261222066,
#  'man.he': 0.6967868570073951,
#  'triathletes': 0.6967868570073951,
#  'mint': 0.6967868570073951,
#  'titanfall': 0.6967868570073951,
#  'awami': -0.6895075041124956,
#  'oppa': 0.6967868570073951,
#  'tonight': -0.268294039036192,
#  'ifeelyou': -0.6895075041124956,
#  'tamang': 0.6967868570073951,
#  'excl': 0.6967868570073951,
#  'company': 0.0036396764474497336,
#  'party': -0.2840423960043313,
#  'selway': 0.6967868570073951,
#  'mid-end': -0.6895075041124956,
#  'tameside': 0.6967868570073951,
#  'definite': -0.6895075041124956,
#  'felt': -0.21950387486675996,
#  'usual': 0.40910478455561416,
#  'ign': 1.1022519651155596,
#  'controversy': -0.6895075041124956,
#  'distracted': -0.6895075041124956,
#  'detail': 2.0830812181272855,
#  'ཀ': -0.6895075041124956,
#  'upset': -1.6057982359866505,
#  'notification': 0.40910478455561416,
#  'translation': 0.6967868570073951,
#  'willy': -0.6895075041124956,
#  'wbu': -0.6895075041124956,
#  ...}

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    """
    Predicts the given tweet's sentiment 
    with the trained Naive Bayes classifier.
    """
    word_l = pre.process_tweet(tweet)
    p = 0
    p += logprior

    for word in word_l:
        if word in loglikelihood:
            p += loglikelihood[word]

    return p

# %%
tweet = "All those moments will be lost in time, \
        like tears in rain. Time to die."
print(naive_bayes_predict(tweet, logprior, loglikelihood))

tweet = "I hate being bipolar, it's awesome"
print(naive_bayes_predict(tweet, logprior, loglikelihood))

tweet = "It’s a good thing I don’t like spinach, \
        because if I did, I’d eat it, \
        and I can’t stand the stuff."
print(naive_bayes_predict(tweet, logprior, loglikelihood))
# Out:
# -5.037156202790864
# 0.14081074551942208
# -0.758299100914187

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    accuracy = 0

    y_hats = []
    for tweet in test_x:
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            y_hat_i = 1
        else:
            y_hat_i = 0
        y_hats.append(y_hat_i)

    error = np.mean(np.absolute(y_hats-test_y))
    accuracy = 1 - error

    return accuracy

# %%
acc = test_naive_bayes(test_x, test_y, logprior, loglikelihood)
print(f"Accuracy: {acc:.2%}")
# Out:
# Accuracy: 99.15%

# %% [markdown]
# Naive Bayes algoritmasını kullanmadan, kelime frekansları ile pozitiflik/negatiflik oranı ölçen fonksiyonlar:

# %%
def get_ratio(freqs, word):
    pos_neg_ratio = {"positive": lookup(freqs, word, 1), 
                     "negative": lookup(freqs, word, 0), 
                     "ratio": 0.0}
    pos_neg_ratio["ratio"] = (pos_neg_ratio["positive"] + 1) / (pos_neg_ratio["negative"] + 1)

    return pos_neg_ratio


def get_words_by_threshold(freqs, label, threshold):
    word_list = {}

    for key in freqs.keys():
        word, _ = key
        pos_neg_ratio = get_ratio(freqs, word)

        if label == 1 and pos_neg_ratio["ratio"] >= threshold:
            word_list[word] = pos_neg_ratio
        elif label == 0 and pos_neg_ratio["ratio"] <= threshold:
            word_list[word] = pos_neg_ratio

    return word_list

# %%
get_words_by_threshold(freqs, 0, 1)
# Out:
# {'odd': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  ':/': {'positive': 5, 'negative': 8, 'ratio': 0.6666666666666666},
#  'please': {'positive': 78, 'negative': 242, 'ratio': 0.32510288065843623},
#  'contact': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'centre': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'able': {'positive': 6, 'negative': 17, 'ratio': 0.3888888888888889},
#  'listen': {'positive': 13, 'negative': 14, 'ratio': 0.9333333333333333},
#  'last': {'positive': 39, 'negative': 51, 'ratio': 0.7692307692307693},
#  'get': {'positive': 223, 'negative': 271, 'ratio': 0.8235294117647058},
#  'mark': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'fb': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'long': {'positive': 28, 'negative': 35, 'ratio': 0.8055555555555556},
#  'thought': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  '’': {'positive': 17, 'negative': 19, 'ratio': 0.9},
#  'enough': {'positive': 16, 'negative': 18, 'ratio': 0.8947368421052632},
#  'time': {'positive': 97, 'negative': 123, 'ratio': 0.7903225806451613},
#  'dd': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'short': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'system': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'buy': {'positive': 11, 'negative': 17, 'ratio': 0.6666666666666666},
#  'go': {'positive': 138, 'negative': 228, 'ratio': 0.6069868995633187},
#  'bye': {'positive': 5, 'negative': 6, 'ratio': 0.8571428571428571},
#  'app': {'positive': 11, 'negative': 11, 'ratio': 1.0},
#  'name': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'already': {'positive': 19, 'negative': 41, 'ratio': 0.47619047619047616},
#  "what's": {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'age': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'entry': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'card': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'range': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'today': {'positive': 86, 'negative': 88, 'ratio': 0.9775280898876404},
#  'lunch': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'help': {'positive': 35, 'negative': 43, 'ratio': 0.8181818181818182},
#  'screenshot': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'work': {'positive': 87, 'negative': 101, 'ratio': 0.8627450980392157},
#  'need': {'positive': 61, 'negative': 85, 'ratio': 0.7209302325581395},
#  'u': {'positive': 129, 'negative': 151, 'ratio': 0.8552631578947368},
#  "i've": {'positive': 25, 'negative': 64, 'ratio': 0.4},
#  'season': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'yeah': {'positive': 24, 'negative': 30, 'ratio': 0.8064516129032258},
#  'year': {'positive': 33, 'negative': 37, 'ratio': 0.8947368421052632},
#  'rest': {'positive': 9, 'negative': 17, 'ratio': 0.5555555555555556},
#  'bed': {'positive': 8, 'negative': 10, 'ratio': 0.8181818181818182},
#  'fix': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'dream': {'positive': 17, 'negative': 17, 'ratio': 1.0},
#  'leave': {'positive': 20, 'negative': 52, 'ratio': 0.39622641509433965},
#  'kik': {'positive': 15, 'negative': 52, 'ratio': 0.3018867924528302},
#  'kikme': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'tinder': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'nsfw': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'akua': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'come': {'positive': 70, 'negative': 88, 'ratio': 0.797752808988764},
#  'house': {'positive': 4, 'negative': 12, 'ratio': 0.38461538461538464},
#  'result': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'watch': {'positive': 30, 'negative': 57, 'ratio': 0.5344827586206896},
#  'buuut': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'oh': {'positive': 11, 'negative': 19, 'ratio': 0.6},
#  'make': {'positive': 106, 'negative': 110, 'ratio': 0.963963963963964},
#  'feel': {'positive': 28, 'negative': 107, 'ratio': 0.26851851851851855},
#  'never': {'positive': 31, 'negative': 42, 'ratio': 0.7441860465116279},
#  'anyone': {'positive': 7, 'negative': 13, 'ratio': 0.5714285714285714},
#  'kpop': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'flesh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'wish': {'positive': 29, 'negative': 63, 'ratio': 0.46875},
#  'epic': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'jordan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fake': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'im': {'positive': 38, 'negative': 106, 'ratio': 0.3644859813084112},
#  'exactly': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'line': {'positive': 6, 'negative': 7, 'ratio': 0.875},
#  'normally': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'asleep': {'positive': 7, 'negative': 17, 'ratio': 0.4444444444444444},
#  'one': {'positive': 8, 'negative': 25, 'ratio': 0.34615384615384615},
#  'talk': {'positive': 37, 'negative': 40, 'ratio': 0.926829268292683},
#  'sooo': {'positive': 6, 'negative': 12, 'ratio': 0.5384615384615384},
#  'someone': {'positive': 29, 'negative': 39, 'ratio': 0.75},
#  'bet': {'positive': 6, 'negative': 8, 'ratio': 0.7777777777777778},
#  'fit': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'green': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'midnight': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sun': {'positive': 6, 'negative': 8, 'ratio': 0.7777777777777778},
#  'sg': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'conference': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'asia': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'change': {'positive': 20, 'negative': 22, 'ratio': 0.9130434782608695},
#  'mama': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stand': {'positive': 5, 'negative': 6, 'ratio': 0.8571428571428571},
#  'baby': {'positive': 17, 'negative': 37, 'ratio': 0.47368421052631576},
#  'cute': {'positive': 21, 'negative': 36, 'ratio': 0.5945945945945946},
#  "can't": {'positive': 31, 'negative': 148, 'ratio': 0.21476510067114093},
#  'yet': {'positive': 12, 'negative': 29, 'ratio': 0.43333333333333335},
#  'still': {'positive': 37, 'negative': 104, 'ratio': 0.3619047619047619},
#  'think': {'positive': 63, 'negative': 87, 'ratio': 0.7272727272727273},
#  'figure': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'drain': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'gotta': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'parent': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'maybe': {'positive': 17, 'negative': 19, 'ratio': 0.9},
#  'sometimes': {'positive': 9, 'negative': 13, 'ratio': 0.7142857142857143},
#  'al': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'choose': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'eh': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'take': {'positive': 38, 'negative': 51, 'ratio': 0.75},
#  'care': {'positive': 10, 'negative': 11, 'ratio': 0.9166666666666666},
#  'finally': {'positive': 13, 'negative': 20, 'ratio': 0.6666666666666666},
#  'fuck': {'positive': 17, 'negative': 39, 'ratio': 0.45},
#  'gift': {'positive': 7, 'negative': 9, 'ratio': 0.8},
#  'yeahhh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'really': {'positive': 66, 'negative': 103, 'ratio': 0.6442307692307693},
#  'gym': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'monday': {'positive': 6, 'negative': 7, 'ratio': 0.875},
#  'nude': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'sleep': {'positive': 36, 'negative': 73, 'ratio': 0.5},
#  'want': {'positive': 69, 'negative': 184, 'ratio': 0.3783783783783784},
#  'mom': {'positive': 7, 'negative': 10, 'ratio': 0.7272727272727273},
#  'obviously': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'charm': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stage': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'stalk': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'monica': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'miss': {'positive': 17, 'negative': 240, 'ratio': 0.07468879668049792},
#  'try': {'positive': 34, 'negative': 55, 'ratio': 0.625},
#  'tonight': {'positive': 15, 'negative': 20, 'ratio': 0.7619047619047619},
#  'tomato': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'basil': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'right': {'positive': 38, 'negative': 41, 'ratio': 0.9285714285714286},
#  'back': {'positive': 74, 'negative': 98, 'ratio': 0.7575757575757576},
#  'even': {'positive': 25, 'negative': 50, 'ratio': 0.5098039215686274},
#  'chance': {'positive': 3, 'negative': 14, 'ratio': 0.26666666666666666},
#  'ice': {'positive': 6, 'negative': 29, 'ratio': 0.23333333333333334},
#  'cream': {'positive': 6, 'negative': 27, 'ratio': 0.25},
#  'stay': {'positive': 20, 'negative': 21, 'ratio': 0.9545454545454546},
#  'home': {'positive': 20, 'negative': 52, 'ratio': 0.39622641509433965},
#  'soon': {'positive': 38, 'negative': 40, 'ratio': 0.9512195121951219},
#  'appear': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'w': {'positive': 13, 'negative': 16, 'ratio': 0.8235294117647058},
#  'wan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sit': {'positive': 6, 'negative': 7, 'ratio': 0.875},
#  'luke': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'inter': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'small': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'railway': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'west': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'smh': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'live': {'positive': 20, 'negative': 27, 'ratio': 0.75},
#  'megan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ah': {'positive': 11, 'negative': 14, 'ratio': 0.8},
#  'goood': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'edward': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mein': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'josh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'always': {'positive': 48, 'negative': 48, 'ratio': 1.0},
#  'picture': {'positive': 7, 'negative': 14, 'ratio': 0.5333333333333333},
#  'timing': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'feeling': {'positive': 5, 'negative': 24, 'ratio': 0.24},
#  'yesterday': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'song': {'positive': 16, 'negative': 25, 'ratio': 0.6538461538461539},
#  'ever': {'positive': 19, 'negative': 25, 'ratio': 0.7692307692307693},
#  'totally': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'different': {'positive': 7, 'negative': 7, 'ratio': 1.0},
#  'clean': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  "i'm": {'positive': 139, 'negative': 263, 'ratio': 0.5303030303030303},
#  'water': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'drive': {'positive': 9, 'negative': 13, 'ratio': 0.7142857142857143},
#  'wanna': {'positive': 23, 'negative': 71, 'ratio': 0.3333333333333333},
#  'skype': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'friendly': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'marketing': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'hour': {'positive': 24, 'negative': 26, 'ratio': 0.9259259259259259},
#  'delay': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'actually': {'positive': 13, 'negative': 18, 'ratio': 0.7368421052631579},
#  'guess': {'positive': 8, 'negative': 13, 'ratio': 0.6428571428571429},
#  'train': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'shift': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'sunburn': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'warm': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'ireland': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'sight': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fr': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'hug': {'positive': 11, 'negative': 20, 'ratio': 0.5714285714285714},
#  'uu': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'fluffy': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'inside': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'trip': {'positive': 11, 'negative': 11, 'ratio': 1.0},
#  'december': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'dude': {'positive': 6, 'negative': 10, 'ratio': 0.6363636363636364},
#  'pain': {'positive': 7, 'negative': 12, 'ratio': 0.6153846153846154},
#  'solo': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'move': {'positive': 9, 'negative': 10, 'ratio': 0.9090909090909091},
#  'smell': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'teen': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'spirit': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'rip': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'wake': {'positive': 13, 'negative': 29, 'ratio': 0.4666666666666667},
#  'gonna': {'positive': 16, 'negative': 44, 'ratio': 0.37777777777777777},
#  'much': {'positive': 73, 'negative': 116, 'ratio': 0.6324786324786325},
#  'together': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'end': {'positive': 13, 'negative': 36, 'ratio': 0.3783783783783784},
#  'rain': {'positive': 18, 'negative': 33, 'ratio': 0.5588235294117647},
#  'forever': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'bug': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'bite': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'bracelet': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'game': {'positive': 23, 'negative': 25, 'ratio': 0.9230769230769231},
#  'phone': {'positive': 16, 'negative': 26, 'ratio': 0.6296296296296297},
#  'derek': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'use': {'positive': 30, 'negative': 31, 'ratio': 0.96875},
#  'man': {'positive': 16, 'negative': 24, 'ratio': 0.68},
#  'traffic': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'stress': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'turn': {'positive': 13, 'negative': 13, 'ratio': 1.0},
#  'omg': {'positive': 10, 'negative': 41, 'ratio': 0.2619047619047619},
#  'difference': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'say': {'positive': 58, 'negative': 76, 'ratio': 0.7662337662337663},
#  'europe': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'rise': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'find': {'positive': 30, 'negative': 55, 'ratio': 0.5535714285714286},
#  'hard': {'positive': 9, 'negative': 33, 'ratio': 0.29411764705882354},
#  'believe': {'positive': 7, 'negative': 11, 'ratio': 0.6666666666666666},
#  'coz': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'true': {'positive': 19, 'negative': 19, 'ratio': 1.0},
#  'high': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'people': {'positive': 42, 'negative': 57, 'ratio': 0.7413793103448276},
#  'mana': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'evening': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'sort': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'hair': {'positive': 6, 'negative': 16, 'ratio': 0.4117647058823529},
#  'tbh': {'positive': 5, 'negative': 11, 'ratio': 0.5},
#  'jacob': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'g': {'positive': 7, 'negative': 7, 'ratio': 1.0},
#  'reading': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'conversation': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'online': {'positive': 4, 'negative': 13, 'ratio': 0.35714285714285715},
#  'allah': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'training': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'youre': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'town': {'positive': 3, 'negative': 12, 'ratio': 0.3076923076923077},
#  'piss': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'terrible': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  'lynettelowe': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'snapchat': {'positive': 7, 'negative': 19, 'ratio': 0.4},
#  'kikmenow': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'snapme': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'amazon': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'kikmeguys': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'grow': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'rt': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'fly': {'positive': 5, 'negative': 9, 'ratio': 0.6},
#  'cyber': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'coach': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'mango': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'marvellous': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mean': {'positive': 21, 'negative': 42, 'ratio': 0.5116279069767442},
#  'hr': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'hai': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'food': {'positive': 6, 'negative': 12, 'ratio': 0.5384615384615384},
#  'brooklyn': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'awake': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'awww': {'positive': 12, 'negative': 19, 'ratio': 0.65},
#  'spam': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'folder': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'claim': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'rted': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'legs': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hurt': {'positive': 4, 'negative': 33, 'ratio': 0.14705882352941177},
#  'bad': {'positive': 17, 'negative': 70, 'ratio': 0.2535211267605634},
#  'saturday': {'positive': 5, 'negative': 10, 'ratio': 0.5454545454545454},
#  'fat': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'co': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'eat': {'positive': 6, 'negative': 27, 'ratio': 0.25},
#  '´': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'google': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'account': {'positive': 17, 'negative': 17, 'ratio': 1.0},
#  'everything': {'positive': 10, 'negative': 14, 'ratio': 0.7333333333333333},
#  'literally': {'positive': 5, 'negative': 13, 'ratio': 0.42857142857142855},
#  "they're": {'positive': 10, 'negative': 13, 'ratio': 0.7857142857142857},
#  'meet': {'positive': 22, 'negative': 22, 'ratio': 1.0},
#  'sigh': {'positive': 3, 'negative': 13, 'ratio': 0.2857142857142857},
#  'happen': {'positive': 12, 'negative': 43, 'ratio': 0.29545454545454547},
#  'fair': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'rush': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'selfie': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  '♥': {'positive': 13, 'negative': 20, 'ratio': 0.6666666666666666},
#  'sex': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  "he's": {'positive': 10, 'negative': 19, 'ratio': 0.55},
#  'throw': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'exhausted': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ruin': {'positive': 5, 'negative': 10, 'ratio': 0.5454545454545454},
#  'internet': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'price': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'pay': {'positive': 8, 'negative': 16, 'ratio': 0.5294117647058824},
#  'net': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'education': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'powerful': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'weapon': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'pakistan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stream': {'positive': 12, 'negative': 20, 'ratio': 0.6190476190476191},
#  'faith': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'school': {'positive': 9, 'negative': 22, 'ratio': 0.43478260869565216},
#  'uk': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'wrong': {'positive': 9, 'negative': 27, 'ratio': 0.35714285714285715},
#  'remember': {'positive': 9, 'negative': 11, 'ratio': 0.8333333333333334},
#  'aww': {'positive': 8, 'negative': 17, 'ratio': 0.5},
#  'head': {'positive': 12, 'negative': 18, 'ratio': 0.6842105263157895},
#  'dark': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'hate': {'positive': 7, 'negative': 41, 'ratio': 0.19047619047619047},
#  'cant': {'positive': 13, 'negative': 41, 'ratio': 0.3333333333333333},
#  'fam': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'heart': {'positive': 6, 'negative': 22, 'ratio': 0.30434782608695654},
#  'heat': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'prob': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'sorry': {'positive': 13, 'negative': 117, 'ratio': 0.11864406779661017},
#  'screenshotting': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'gooo': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'old': {'positive': 12, 'negative': 16, 'ratio': 0.7647058823529411},
#  'welsh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ure': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'front': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'heavy': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'spend': {'positive': 3, 'negative': 7, 'ratio': 0.5},
#  'marathon': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'graduate': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'cry': {'positive': 7, 'negative': 37, 'ratio': 0.21052631578947367},
#  'expert': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'yo': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'pi': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'book': {'positive': 14, 'negative': 16, 'ratio': 0.8823529411764706},
#  'tough': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'chill': {'positive': 5, 'negative': 6, 'ratio': 0.8571428571428571},
#  'moment': {'positive': 10, 'negative': 13, 'ratio': 0.7857142857142857},
#  'decide': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'hopefully': {'positive': 10, 'negative': 12, 'ratio': 0.8461538461538461},
#  'depends': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ahhh': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'cop': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'street': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'mental': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'appeal': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'late': {'positive': 14, 'negative': 24, 'ratio': 0.6},
#  'isi': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'c': {'positive': 6, 'negative': 8, 'ratio': 0.7777777777777778},
#  'pkwalasawaal': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fever': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'anime': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'order': {'positive': 12, 'negative': 14, 'ratio': 0.8666666666666667},
#  'room': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'car': {'positive': 5, 'negative': 11, 'ratio': 0.5},
#  'hahaha': {'positive': 11, 'negative': 11, 'ratio': 1.0},
#  'story': {'positive': 10, 'negative': 11, 'ratio': 0.9166666666666666},
#  'due': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'march': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'regret': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'rn': {'positive': 4, 'negative': 13, 'ratio': 0.35714285714285715},
#  'wtf': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  "there's": {'positive': 6, 'negative': 13, 'ratio': 0.5},
#  'thrown': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'middle': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'month': {'positive': 11, 'negative': 18, 'ratio': 0.631578947368421},
#  'babe': {'positive': 7, 'negative': 15, 'ratio': 0.5},
#  'mother': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'determination': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'lonely': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'e': {'positive': 5, 'negative': 8, 'ratio': 0.6666666666666666},
#  'alert': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'da': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'dang': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'massive': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'niamh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'selena': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'trade': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'tire': {'positive': 4, 'negative': 17, 'ratio': 0.2777777777777778},
#  'leg': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'bb': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'promote': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'album': {'positive': 5, 'negative': 11, 'ratio': 0.5},
#  'write': {'positive': 13, 'negative': 13, 'ratio': 1.0},
#  'otwolgrandtrailer': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'odds': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ni': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'sunday': {'positive': 6, 'negative': 7, 'ratio': 0.875},
#  'august': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'apartment': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'kill': {'positive': 3, 'negative': 13, 'ratio': 0.2857142857142857},
#  'sadly': {'positive': 1, 'negative': 10, 'ratio': 0.18181818181818182},
#  'issue': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'sad': {'positive': 4, 'negative': 102, 'ratio': 0.04854368932038835},
#  'win': {'positive': 12, 'negative': 23, 'ratio': 0.5416666666666666},
#  'hardly': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'break': {'positive': 8, 'negative': 12, 'ratio': 0.6923076923076923},
#  'past': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'jim': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'shopping': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'cake': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'reach': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'scorch': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'summer': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'woman': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'expect': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'dont': {'positive': 11, 'negative': 39, 'ratio': 0.3},
#  'v': {'positive': 8, 'negative': 10, 'ratio': 0.8181818181818182},
#  'alter': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'near': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'colour': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'n': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'forget': {'positive': 20, 'negative': 20, 'ratio': 1.0},
#  'japanese': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'kitty': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'close': {'positive': 12, 'negative': 16, 'ratio': 0.7647058823529411},
#  'alarm': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mad': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'xd': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'waste': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'completely': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'tho': {'positive': 10, 'negative': 23, 'ratio': 0.4583333333333333},
#  'outside': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'holiday': {'positive': 9, 'negative': 15, 'ratio': 0.625},
#  'ta': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'guys': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  '😘': {'positive': 9, 'negative': 9, 'ratio': 1.0},
#  '️': {'positive': 11, 'negative': 12, 'ratio': 0.9230769230769231},
#  'pack': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'truck': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'otp': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'report': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'unit': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'clash': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  '👌': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'followback': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'legit': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'dead': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'news': {'positive': 16, 'negative': 18, 'ratio': 0.8947368421052632},
#  'kms': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'somewhere': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'dog': {'positive': 6, 'negative': 12, 'ratio': 0.5384615384615384},
#  'cat': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'ugh': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'leeds': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'wasnt': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fifth': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'available': {'positive': 6, 'negative': 8, 'ratio': 0.7777777777777778},
#  'pa': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'ba': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'ng': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'coldplay': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'scientist': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'an': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'bill': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'pocket': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'jean': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'staff': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mum': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'beg': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'tired': {'positive': 1, 'negative': 19, 'ratio': 0.1},
#  'dance': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'tell': {'positive': 26, 'negative': 29, 'ratio': 0.9},
#  'truth': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'pls': {'positive': 6, 'negative': 24, 'ratio': 0.28},
#  '4-6': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'key': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'far': {'positive': 14, 'negative': 16, 'ratio': 0.8823529411764706},
#  'voice': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'physic': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stop': {'positive': 14, 'negative': 35, 'ratio': 0.4166666666666667},
#  'swag': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mia': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'seem': {'positive': 8, 'negative': 12, 'ratio': 0.6923076923076923},
#  'somebody': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sell': {'positive': 1, 'negative': 10, 'ratio': 0.18181818181818182},
#  'understand': {'positive': 6, 'negative': 11, 'ratio': 0.5833333333333334},
#  'beach': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'movie': {'positive': 17, 'negative': 17, 'ratio': 1.0},
#  'nash': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'chocolate': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'tea': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'episode': {'positive': 5, 'negative': 9, 'ratio': 0.6},
#  'assignment': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'hong': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'kong': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'dj': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'ohh': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'hii': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'di': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'yung': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ko': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  '</3': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'ugly': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'la': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'prize': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  '(:': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'fucking': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'ill': {'positive': 5, 'negative': 10, 'ratio': 0.5454545454545454},
#  'sick': {'positive': 1, 'negative': 32, 'ratio': 0.06060606060606061},
#  'advert': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'madness': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'bollywood': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'nothing': {'positive': 13, 'negative': 19, 'ratio': 0.7},
#  'pure': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'goodbye': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'bitch': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'hbd': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'jai': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fast': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'ang': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'kiss': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'bruise': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  '😂': {'positive': 10, 'negative': 14, 'ratio': 0.7333333333333333},
#  'low': {'positive': 6, 'negative': 9, 'ratio': 0.7},
#  'match': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'harry': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'bc': {'positive': 6, 'negative': 32, 'ratio': 0.21212121212121213},
#  "how's": {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'lick': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  '. .': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  '“': {'positive': 7, 'negative': 14, 'ratio': 0.5333333333333333},
#  'emu': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'kid': {'positive': 11, 'negative': 15, 'ratio': 0.75},
#  '2-3': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ol': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'bone': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'die': {'positive': 8, 'negative': 14, 'ratio': 0.6},
#  'xo': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'edm': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'wild': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'maganda': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'busy': {'positive': 11, 'negative': 21, 'ratio': 0.5454545454545454},
#  'he': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'hang': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'facebook': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'kikmeboys': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'scar': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'office': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'weather': {'positive': 7, 'negative': 25, 'ratio': 0.3076923076923077},
#  'wedding': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'cast': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'election': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'peace': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'steel': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'wednesday': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'swear': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  '😭': {'positive': 2, 'negative': 22, 'ratio': 0.13043478260869565},
#  'favourite': {'positive': 8, 'negative': 8, 'ratio': 1.0},
#  'shit': {'positive': 11, 'negative': 25, 'ratio': 0.46153846153846156},
#  'healthy': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'madrid': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'adam': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'certain': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'exam': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'sale': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'cannot': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'disappoint': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'paper': {'positive': 3, 'negative': 12, 'ratio': 0.3076923076923077},
#  'crack': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'instant': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'possibly': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'gosh': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'ka': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'venice': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'manual': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'bomb': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'fee': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'chloe': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'away': {'positive': 11, 'negative': 22, 'ratio': 0.5217391304347826},
#  'juan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'bby': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'clip': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'lose': {'positive': 2, 'negative': 25, 'ratio': 0.11538461538461539},
#  'allow': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'gurl': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'suck': {'positive': 8, 'negative': 20, 'ratio': 0.42857142857142855},
#  'ahead': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'tear': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'youuu': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'ako': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'daddy': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  '”': {'positive': 4, 'negative': 11, 'ratio': 0.4166666666666667},
#  'bank': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'yup': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'wet': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  'foot': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'bt': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'denim': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'run': {'positive': 11, 'negative': 13, 'ratio': 0.8571428571428571},
#  'count': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'teacher': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'roll': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'memory': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'quote': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'weird': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'wife': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'poor': {'positive': 3, 'negative': 24, 'ratio': 0.16},
#  'brother': {'positive': 3, 'negative': 9, 'ratio': 0.4},
#  'lucky': {'positive': 7, 'negative': 12, 'ratio': 0.6153846153846154},
#  'rate': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'hotel': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'safe': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'shes': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'unnie': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'pass': {'positive': 8, 'negative': 9, 'ratio': 0.9},
#  'ip': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'abt': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ago': {'positive': 6, 'negative': 15, 'ratio': 0.4375},
#  'slow': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'soft': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'melt': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mouth': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'easily': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  "who's": {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'worthy': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'decent': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'aku': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'outfit': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'tree': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'important': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'party': {'positive': 8, 'negative': 11, 'ratio': 0.75},
#  'facetime': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'announce': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'broken': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'light': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'ahh': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'stupid': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'slap': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'door': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'vip': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'general': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'seat': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'early': {'positive': 8, 'negative': 14, 'ratio': 0.6},
#  'london': {'positive': 4, 'negative': 10, 'ratio': 0.45454545454545453},
#  'fresh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'driver': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'f': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'cut': {'positive': 2, 'negative': 15, 'ratio': 0.1875},
#  'famous': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'client': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'p': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'alive': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'steak': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'laptop': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'guinea': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'pig': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'bestfriends': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sa': {'positive': 6, 'negative': 10, 'ratio': 0.6363636363636364},
#  'apple': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'charles': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'model': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'butter': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'brb': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'force': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'discuss': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'snake': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'perform': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'max': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'return': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'bud': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'competition': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'itunes': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  '💜': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'daft': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'trouble': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ben': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'active': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'distance': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'final': {'positive': 11, 'negative': 11, 'ratio': 1.0},
#  'stockholm': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'blonde': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'box': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'cutest': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'pal': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'boot': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'ps3': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fear': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fell': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'unblock': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'manually': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'tweak': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'php': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fall': {'positive': 5, 'negative': 16, 'ratio': 0.35294117647058826},
#  'bus': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'everyday': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'laugh': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'hk': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'originally': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'apart': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'advanced': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hold': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'switch': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'lap': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'lu': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'class': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'normal': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'whats': {'positive': 3, 'negative': 7, 'ratio': 0.5},
#  'height': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'ti5': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'spot': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'jealous': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'spree': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'donation': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'h': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'hun': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'math': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'channel': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'push': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'goat': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'whole': {'positive': 5, 'negative': 10, 'ratio': 0.5454545454545454},
#  'wide': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'wat': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'campaign': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'absolute': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'havent': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'nth': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mo': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'realise': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'anymore': {'positive': 3, 'negative': 17, 'ratio': 0.2222222222222222},
#  'honestly': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'relationship': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'personal': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'mubank': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'bright': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'path': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'bos': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'birmingham': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'serve': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sushi': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  '�': {'positive': 2, 'negative': 21, 'ratio': 0.13636363636363635},
#  '. . .': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'imran': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'size': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'wallet': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  '💗': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'hahahaha': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'wear': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'evil': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'owww': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'kiksexting': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'killer': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'band': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'money': {'positive': 5, 'negative': 20, 'ratio': 0.2857142857142857},
#  'hahahahaha': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'evet': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'wifi': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'leanneriner': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'porno': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'weloveyounamjoon': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'emotional': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'crap': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'burn': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'sexy': {'positive': 7, 'negative': 11, 'ratio': 0.6666666666666666},
#  'hand': {'positive': 4, 'negative': 11, 'ratio': 0.4166666666666667},
#  'dnt': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'nobody': {'positive': 2, 'negative': 9, 'ratio': 0.3},
#  'offer': {'positive': 7, 'negative': 9, 'ratio': 0.8},
#  'af': {'positive': 6, 'negative': 10, 'ratio': 0.6363636363636364},
#  'display': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'enable': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'company': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'tweeps': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ep': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'control': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'toss': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'climb': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'cuddle': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'headline': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'total': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'particular': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'bag': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'slr': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'som': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'forest': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'lie': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'urself': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'double': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'black': {'positive': 4, 'negative': 10, 'ratio': 0.45454545454545453},
#  'bore': {'positive': 4, 'negative': 11, 'ratio': 0.4166666666666667},
#  'female': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'tour': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'muchhh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'tmr': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'breakfast': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  '):': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'maine': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'tak': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'ye': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'nhi': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'se': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'cheese': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'pizza': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'lil': {'positive': 3, 'negative': 7, 'ratio': 0.5},
#  'chain': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'everybody': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'bunch': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'acc': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'til': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'freedom': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'round': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'kepo': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'clearly': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'na': {'positive': 4, 'negative': 11, 'ratio': 0.4166666666666667},
#  'scene': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'elfindelmundo': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sexi': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'situation': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'bottle': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'shade': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'grey': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'edition': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ate': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'whenever': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'apology': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'dad': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'being': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mere': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'charge': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'ce': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'barkada': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'pull': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'lately': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'notice': {'positive': 7, 'negative': 14, 'ratio': 0.5333333333333333},
#  'hide': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'gettin': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'hella': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'hell': {'positive': 3, 'negative': 10, 'ratio': 0.36363636363636365},
#  'park': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'hop': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'elf': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'flight': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'jennyjean': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sabadodeganarseguidores': {'positive': 1,
#   'negative': 2,
#   'ratio': 0.6666666666666666},
#  'sexysasunday': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'ganda': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'steam': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'goin': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'chicken': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'empty': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'kikgirl': {'positive': 4, 'negative': 12, 'ratio': 0.38461538461538464},
#  'orgasm': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'phonesex': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'jk': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'vidcon': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'anxious': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'white': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'wall': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'there': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'afraid': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'effect': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'boring': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'isolate': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'huhu': {'positive': 3, 'negative': 14, 'ratio': 0.26666666666666666},
#  'english': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  '. ..': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'amin': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'goal': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'state': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'le': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'discovery': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'cousin': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'tou': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'wont': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'unmarried': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'finger': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'alot': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'exercise': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hungry': {'positive': 2, 'negative': 13, 'ratio': 0.21428571428571427},
#  'kit': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'knw': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'block': {'positive': 2, 'negative': 9, 'ratio': 0.3},
#  'exist': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'damn': {'positive': 3, 'negative': 22, 'ratio': 0.17391304347826086},
#  'college': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'aaahhh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'jen': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'information': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'restrict': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'huh': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'annoy': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'swan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'b': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'currently': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'blast': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sing': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'disney': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hain': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'case': {'positive': 5, 'negative': 6, 'ratio': 0.8571428571428571},
#  'male': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'icon': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'lmao': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  'bae': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'reply': {'positive': 5, 'negative': 11, 'ratio': 0.5},
#  'rude': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'lounge': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'shoulder': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'insecurity': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'nh': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'burnt': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'serious': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'flip': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'session': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'pre': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'comic': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'none': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'circle': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'burst': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'georgie': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sometime': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'crazy': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'lah': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'reunite': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sea': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'comeback': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'gross': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'treat': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'jam': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stuck': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'worst': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'wag': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'bum': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'spring': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'noise': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'sept': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'upset': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'clothes': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'doom': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'nasty': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hall': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'obsess': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'third': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'turkey': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'bruce': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fire': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'following': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'rob': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'finland': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'airport': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'plane': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'yan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'cartoon': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stick': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'bff': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'attempt': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'law': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'load': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'slightly': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'ew': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'survive': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'lead': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'vocal': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'jane': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hawk': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'history': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'ring': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'breathe': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'goodluck': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mockingjay': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'felt': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'san': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'jump': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'aj': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'action': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sc': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'yah': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  ':(': {'positive': 1, 'negative': 3582, 'ratio': 0.0005581914596706671},
#  'kingdom': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'brill': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'simple': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'awe': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'abroad': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'moviee': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'soo': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'drug': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'champagne': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'fc': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'correct': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'portrait': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'server': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'quiet': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'trend': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'pet': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'painting': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'deal': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'industry': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'frank': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'july': {'positive': 9, 'negative': 11, 'ratio': 0.8333333333333334},
#  'awhile': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'robert': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'cross': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'eid': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'tokyo': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'l': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'detailed': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'data': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'amsterdam': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'booty': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'step': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'option': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'stable': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'unknown': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'gf': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'supportive': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'vine': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'face': {'positive': 6, 'negative': 17, 'ratio': 0.3888888888888889},
#  'answer': {'positive': 6, 'negative': 9, 'ratio': 0.7},
#  'angelica': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  ...}

# %% [markdown]
# Using mined data:

# %%
def sentiment_saver(file_name_wo_ex: str):
    df = pd.read_csv('tripadvisor_en.csv', sep='\t')
    df['label'] = -1
    
    for idx, line in enumerate(df.text.to_list()): 
        label = int(naive_bayes_predict(line, logprior, loglikelihood) >= 0)
        df['label'].iloc[idx] = label
        
    df.to_csv('tripadvisor_en_labeled.csv', sep='\t')
    
    return df

# %%
df_2021 = sentiment_saver("full_data")
# Out:
# /tmp/ipykernel_121493/3616511598.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'].iloc[idx] = label

# %%
df_2021.head()
# Out:
#    Unnamed: 0                                 title  \
# 0           0   Too small! Also this is not a city.
# 1           1  Fascinating but physically demanding
# 2           2      Visit before Kaymakli or skip it
# 3           3                        Worth a visit.
# 4           4                      Unique as can be
#
#                                                 text travel_date  rating  \
# 0  The cave was kind of interesting but tour guid...     2022-01       3
# 1  Derinkuyu is a fascinating underground city th...     2022-01       4
# 2  Derinkuyu is the biggest underground town in t...     2021-08       3
# 3  Very enjoyable - but really intense... Narrow ...     2021-07       5
# 4  If you want a unique experience, then any of C...     2021-03       5
#
#    location  label
# 0         1      1
# 1         1      0
# 2         1      1
# 3         1      1
# 4         1      1

# %%
data = [sent_val for sent_val in df_2021["label"].value_counts()]
labels = ["Negative", "Positive"]
plt.xticks(range(len(data)), labels)
plt.xlabel("Sentiment")
plt.ylabel("Tweet Amount")
plt.title("Sentiment Values of Trip Advisor Dataset (2021)")
plt.bar(range(len(data)), data)
plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
df = [analyzer.polarity_scores(text) 
      for text in df_2021.text.to_list()]
df = pd.DataFrame(df)
df['text'] = df_2021['text']
df['label'] = df_2021['label']
df.to_csv('foo.csv')

# %%
vader_data = (df['compound'] > 0).astype(int).value_counts()
vader_data = [vader_data[i] for i in range(len(vader_data))]
print(vader_data)
labels = ["Negative", "Positive"]
plt.xticks(range(len(vader_data)), labels)
plt.xlabel("Sentiment")
plt.ylabel("Tweet Amount")
plt.title("Sentiment Values of Trip Advisor Dataset (2021)")
plt.bar(range(len(vader_data)), vader_data)
plt.show()
# Out:
# [92, 829]

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

num_bins = 50
n, bins, patches = plt.hist(df['compound'], num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print(f"{y}\t{int(np.sign(y_hat) > 0)}\t{' '.join(pre.process_tweet(x))}")
# Out:
# Truth Predicted Tweet
# 1.0	0
# 1.0	0	truly lateral move know queen bee upward movingonup
# 1.0	0	wake feel incredibly sick idk cause drank starbucks o'clock last night reaction med :)
# 1.0	0	new report talk burn calorie cold work hard warm feel good weather :p
# 1.0	0
# 1.0	0	wanna loser ♥
# 1.0	0
# 1.0	0	park get sunlight
# 1.0	0	uff itna miss karhy thy ap :p
# 0.0	1	lot people suggest still
# 0.0	1	u probs fun david
# 0.0	1	hi unfortunately unable locate original complaint pls dm product detail we'll get back
# 0.0	1	fun osaka super junior lovely watch comeback stage
# 0.0	1	pat jay
# 0.0	1	give work old staff come police later court look job bye bye
# 0.0	1	carter deserve hate deserve single corn chip deserve corn chip
# 0.0	1	thats life get call people havent see year always favour
